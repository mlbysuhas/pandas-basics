# %% [markdown]
# # Pandas Practice
#
# This notebook is dedicated to practicing different tasks with pandas. The solutions are available in a solutions notebook, however, you should always try to figure them out yourself first.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Exercises are based off (and directly taken from) the quick introduction to pandas notebook.
#
# Different tasks will be detailed by comments or text.

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of Five different colours
Colors = pd.Series (["MatBlack","Blue","Green","White","Orange"])

# %%
# View the series of different colours
Colors
# Out:
# 0    MatBlack
# 1        Blue
# 2       Green
# 3       White
# 4      Orange
# dtype: object

# %%
# Create a series of Five different car types and view it
Bikes = pd.Series(["jawa","Bullet","Kawasaki","BMW","Duke"])
Bikes
# Out:
# 0        jawa
# 1      Bullet
# 2    Kawasaki
# 3         BMW
# 4        Duke
# dtype: object

# %%
# Combine the Series of ca"Bikes and colours into a DataFrame
About_bikes=pd.DataFrame ({"Bike_make":Bikes,"Bike_color": Colors})

# %%
# Combine the Series of cars and colours into a DataFrame
About_bikes
# Out:
#   Bike_make Bike_color
# 0      jawa   MatBlack
# 1    Bullet       Blue
# 2  Kawasaki      Green
# 3       BMW      White
# 4      Duke     Orange

# %%
# Import "../data/"Bike-sales.csv" and turn it into a DataFrame
About_Bikes = pd.read_csv("Bike_sales.csv")

# %% [markdown]
# **Note:** Since you've imported `../data/car-sales.csv` as a DataFrame, we'll now refer to this DataFrame as 'the car sales DataFrame'.

# %%
# Export the DataFrame you created to a .csv file
About_Bikes
# Out:
#        Make    Colour  Odometer (KM)  GEARS    Price
# 0      JAWA  MATBLACK         150043      6   230000
# 1    BULLET       Red          87899      5   200000
# 2      JAWA      Blue          32549      6   250000
# 3       BMW     WHITE          11179      6   400000
# 4  KAWASAKI     GREEN         213095      6  2000000
# 5       KTM    ORANGE          99213      6   400000
# 6     HONDA      Blue          45698      4   100000
# 7      HERO      Blue          54738      4   120000
# 8  KAWASAKI     White          60000      6   100000
# 9       KTM     White          31600      6   300000

# %%
# Find the different datatypes of the "Bike data DataFrame
About_Bikes.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# GEARS             int64
# Price             int64
# dtype: object

# %%
# Describe your current"Bike About_Bikes DataFrame using describe()
About_Bikes.describe()
# Out:
#        Odometer (KM)      GEARS         Price
# count      10.000000  10.000000  1.000000e+01
# mean    78601.400000   5.500000  4.100000e+05
# std     61983.471735   0.849837  5.694832e+05
# min     11179.000000   4.000000  1.000000e+05
# 25%     35836.250000   5.250000  1.400000e+05
# 50%     57369.000000   6.000000  2.400000e+05
# 75%     96384.500000   6.000000  3.750000e+05
# max    213095.000000   6.000000  2.000000e+06

# %%
# Get information about your DataFrame using info()
About_Bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   GEARS          10 non-null     int64
#  4   Price          10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %% [markdown]
# What does it show you?

# %%
# Find the length of the About_Bikes DataFrame
len(About_Bikes)
# Out:
# 10

# %%
# Show the first 5 rows of theAbout_Bikes DataFrame
About_Bikes.head()
# Out:
#        Make    Colour  Odometer (KM)  GEARS    Price
# 0      JAWA  MATBLACK         150043      6   230000
# 1    BULLET       Red          87899      5   200000
# 2      JAWA      Blue          32549      6   250000
# 3       BMW     WHITE          11179      6   400000
# 4  KAWASAKI     GREEN         213095      6  2000000

# %%
# Show the first 7 rows of the About_Bikes DataFrame
About_Bikes.head(7)
# Out:
#        Make    Colour  Odometer (KM)  GEARS    Price
# 0      JAWA  MATBLACK         150043      6   230000
# 1    BULLET       Red          87899      5   200000
# 2      JAWA      Blue          32549      6   250000
# 3       BMW     WHITE          11179      6   400000
# 4  KAWASAKI     GREEN         213095      6  2000000
# 5       KTM    ORANGE          99213      6   400000
# 6     HONDA      Blue          45698      4   100000

# %%
# Show the bottom 5 rows of the About_Bikes DataFrame
About_Bikes.tail()
# Out:
#        Make  Colour  Odometer (KM)  GEARS   Price
# 5       KTM  ORANGE          99213      6  400000
# 6     HONDA    Blue          45698      4  100000
# 7      HERO    Blue          54738      4  120000
# 8  KAWASAKI   White          60000      6  100000
# 9       KTM   White          31600      6  300000

# %%
# Use .loc to select the row at index 3 of  About_Bikes DataFrame
About_Bikes.iloc[3]
# Out:
# Make                BMW
# Colour            WHITE
# Odometer (KM)     11179
# GEARS                 6
# Price            400000
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of theAbout_Bikes DataFrame
About_Bikes.loc[3]
# Out:
# Make                BMW
# Colour            WHITE
# Odometer (KM)     11179
# GEARS                 6
# Price            400000
# Name: 3, dtype: object

# %%
# Select the "Odometer (KM)" column from the About_Bikes DataFrame
About_Bikes["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the About_Bikes DataFrame
About_Bikes["Odometer (KM)"].mean()
# Out:
# np.float64(78601.4)

# %%
# Select the rows with over 100,000 kilometers on the Odometer
About_Bikes[About_Bikes['Odometer (KM)'] >  100000]
# Out:
#        Make    Colour  Odometer (KM)  GEARS    Price
# 0      JAWA  MATBLACK         150043      6   230000
# 4  KAWASAKI     GREEN         213095      6  2000000

# %%
# Create a crosstab of the Make and Gears columns
pd.crosstab(About_Bikes["Make"],About_Bikes["GEARS"])
# Out:
# GEARS     4  5  6
# Make
# BMW       0  0  1
# BULLET    0  1  0
# HERO      1  0  0
# HONDA     1  0  0
# JAWA      0  0  2
# KAWASAKI  0  0  2
# KTM       0  0  2

# %%
# Group columns of the About_Bikes DataFrame by the Make column and find the average
About_Bikes.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# GEARS             int64
# Price             int64
# dtype: object

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Create a histogram of the Odometer column using hist()
About_Bikes["Odometer (KM)"].hist()
plt.show()

# %%
# Try to plot the Price column using plot()
About_Bikes["Price"].plot()
plt.show()

# %% [markdown]
# Why didn't it work? Can you think of a solution?
#
# You might want to search for "how to convert a pandas string column to numbers".
#
# And if you're still stuck, check out this [Stack Overflow question and answer on turning a price column into integers](https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas).
#
# See how you can provide the example code there to the problem here.

# %%
# Remove the punctuation from price column
About_Bikes["Price"] = About_Bikes["Price"].astype(str).str.replace(r'[^\w\s]', '', regex=True)

# %%
# Check the changes to the price column
About_Bikes["Price"]
# Out:
# 0     230000
# 1     200000
# 2     250000
# 3     400000
# 4    2000000
# 5     400000
# 6     100000
# 7     120000
# 8     100000
# 9     300000
# Name: Price, dtype: object

# %%
# Remove the two extra zeros at the end of the price column
About_Bikes['Price'] = About_Bikes['Price'].astype(int) // 100

# %%
# Check the changes to the Price column
About_Bikes['Price']
# Out:
# 0     2300
# 1     2000
# 2     2500
# 3     4000
# 4    20000
# 5     4000
# 6     1000
# 7     1200
# 8     1000
# 9     3000
# Name: Price, dtype: int64

# %%
# Change the datatype of the Price column to integers
About_Bikes["Price"]= About_Bikes['Price'].astype(int)
About_Bikes["Price"]
# Out:
# 0     2300
# 1     2000
# 2     2500
# 3     4000
# 4    20000
# 5     4000
# 6     1000
# 7     1200
# 8     1000
# 9     3000
# Name: Price, dtype: int64

# %%
# Lower the strings of the Make column
About_Bikes['Make']=About_Bikes['Make'].str.lower()

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.

# %%
# Make lowering the case of the Make column permanent
About_Bikes['Make']=About_Bikes['Make'].str.lower()

# %%
# Check the About_Bikes DataFrame
About_Bikes
# Out:
#        Make    Colour  Odometer (KM)  GEARS  Price
# 0      jawa  MATBLACK         150043      6   2300
# 1    bullet       Red          87899      5   2000
# 2      jawa      Blue          32549      6   2500
# 3       bmw     WHITE          11179      6   4000
# 4  kawasaki     GREEN         213095      6  20000
# 5       ktm    ORANGE          99213      6   4000
# 6     honda      Blue          45698      4   1000
# 7      hero      Blue          54738      4   1200
# 8  kawasaki     White          60000      6   1000
# 9       ktm     White          31600      6   3000

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the About_Bikes DataFrame with missing data ("../data/Bike-sales-missing-data.csv")
Bike_missing = pd.read_csv("Bike-sales-missing-data.csv")
# Check out the new DataFrame
Bike_missing
# Out:
#        Make    Colour  Odometer  GEARS  Price
# 0      JAWA  MATBLACK  150043.0      6   2300
# 1    BULLET       Red   87899.0      5   2000
# 2      JAWA      Blue       NaN      6   2500
# 3       BMW     WHITE   11179.0      6   4000
# 4  KAWASAKI     GREEN  213095.0      6  20000
# 5       KTM    ORANGE       NaN      6   4000
# 6     HONDA      Blue       NaN      4   1000
# 7      HERO      Blue       NaN      4   1200
# 8  KAWASAKI     White   60000.0      6   1000
# 9       KTM     White   31600.0      6   3000

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
# Fill the Odometer column missing values with the mean of the column inplace
Bike_missing['Odometer'] = Bike_missing['Odometer'].fillna(Bike_missing['Odometer'].mean())

# %%
# View the Bike_missing missing DataFrame and verify the changes
Bike_missing
# Out:
#        Make    Colour       Odometer  GEARS  Price
# 0      JAWA  MATBLACK  150043.000000      6   2300
# 1    BULLET       Red   87899.000000      5   2000
# 2      JAWA      Blue   92302.666667      6   2500
# 3       BMW     WHITE   11179.000000      6   4000
# 4  KAWASAKI     GREEN  213095.000000      6  20000
# 5       KTM    ORANGE   92302.666667      6   4000
# 6     HONDA      Blue   92302.666667      4   1000
# 7      HERO      Blue   92302.666667      4   1200
# 8  KAWASAKI     White   60000.000000      6   1000
# 9       KTM     White   31600.000000      6   3000

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seat" column where every row has a value of 2
About_Bikes["Seats"] =[2,2,2,2,2,2,2,2,2,2,2]
About_Bikes
# Out:
#         Make    Colour  Odometer (KM)  GEARS  Price  Seats
# 0       jawa  MATBLACK         150043      6   2300      2
# 1     bullet       Red          87899      5   2000      2
# 2       jawa      Blue          32549      6   2500      2
# 3        bmw     WHITE          11179      6   4000      2
# 4   kawasaki     GREEN         213095      6  20000      2
# 5        ktm    ORANGE          99213      6   4000      2
# 6      honda      Blue          45698      4   1000      2
# 7       hero      Blue          54738      4   1200      2
# 8   kawasaki     White          60000      6   1000      2
# 9        ktm     White          31600      6   3000      2
# 10     Bajaj       RED          32500      5   5000      2

# %%
#Adding one more Row 
#About_Bikes.loc[len(About_Bikes)] = ["Bajaj", "RED", 32500, 5,2000]
#About_Bikes

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
import random
About_Bikes['Engine Size'] = pd.Series([round(random.uniform(1.3, 4.5), 1) for _ in range(len(About_Bikes))])
About_Bikes
# Out:
#         Make    Colour  Odometer (KM)  GEARS  Price  Seats  Engine Size
# 0       jawa  MATBLACK         150043      6   2300      2          2.9
# 1     bullet       Red          87899      5   2000      2          3.5
# 2       jawa      Blue          32549      6   2500      2          4.1
# 3        bmw     WHITE          11179      6   4000      2          1.5
# 4   kawasaki     GREEN         213095      6  20000      2          3.4
# 5        ktm    ORANGE          99213      6   4000      2          1.6
# 6      honda      Blue          45698      4   1000      2          4.4
# 7       hero      Blue          54738      4   1200      2          2.9
# 8   kawasaki     White          60000      6   1000      2          1.9
# 9        ktm     White          31600      6   3000      2          1.5
# 10     Bajaj       RED          32500      5   5000      2          1.7

# %%
# Create a column which represents the price of a Bike per kilometer
# Then view the DataFrame
About_Bikes['Price_per_Km'] = About_Bikes['Price'] / About_Bikes['Odometer (KM)']
About_Bikes
# Out:
#         Make    Colour  Odometer (KM)  GEARS  Price  Seats  Engine Size  \
# 0       jawa  MATBLACK         150043      6   2300      2          2.9
# 1     bullet       Red          87899      5   2000      2          3.5
# 2       jawa      Blue          32549      6   2500      2          4.1
# 3        bmw     WHITE          11179      6   4000      2          1.5
# 4   kawasaki     GREEN         213095      6  20000      2          3.4
# 5        ktm    ORANGE          99213      6   4000      2          1.6
# 6      honda      Blue          45698      4   1000      2          4.4
# 7       hero      Blue          54738      4   1200      2          2.9
# 8   kawasaki     White          60000      6   1000      2          1.9
# 9        ktm     White          31600      6   3000      2          1.5
# 10     Bajaj       RED          32500      5   5000      2          1.7
#
#     Price_per_Km
# 0       0.015329
# 1       0.022753
# 2       0.076807
# 3       0.357814
# ...

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
About_Bikes_shuffled = About_Bikes.sample(frac=1)
About_Bikes_shuffled
# Out:
#         Make    Colour  Odometer (KM)  GEARS  Price  Seats  Engine Size
# 2       jawa      Blue          32549      6   2500      2          4.1
# 6      honda      Blue          45698      4   1000      2          4.4
# 4   kawasaki     GREEN         213095      6  20000      2          3.4
# 10     Bajaj       RED          32500      5   5000      2          1.7
# 8   kawasaki     White          60000      6   1000      2          1.9
# 5        ktm    ORANGE          99213      6   4000      2          1.6
# 1     bullet       Red          87899      5   2000      2          3.5
# 9        ktm     White          31600      6   3000      2          1.5
# 7       hero      Blue          54738      4   1200      2          2.9
# 3        bmw     WHITE          11179      6   4000      2          1.5
# 0       jawa  MATBLACK         150043      6   2300      2          2.9

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
About_Bikes_shuffled = About_bikes.sample(frac=1).reset_index(drop=True)
About_Bikes_shuffled
# Out:
#   Bike_make Bike_color
# 0    Bullet       Blue
# 1       BMW      White
# 2  Kawasaki      Green
# 3      Duke     Orange
# 4      jawa   MatBlack

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
About_Bikes.rename(columns={'Odometer (KM)': 'Odometer (mi)'}, inplace=True)
About_Bikes
# Out:
#         Make    Colour  GEARS  Price  Seats  Engine Size
# 0       jawa  MATBLACK      6   2300      2          2.9
# 1     bullet       Red      5   2000      2          3.5
# 2       jawa      Blue      6   2500      2          4.1
# 3        bmw     WHITE      6   4000      2          1.5
# 4   kawasaki     GREEN      6  20000      2          3.4
# 5        ktm    ORANGE      6   4000      2          1.6
# 6      honda      Blue      4   1000      2          4.4
# 7       hero      Blue      4   1200      2          2.9
# 8   kawasaki     White      6   1000      2          1.9
# 9        ktm     White      6   3000      2          1.5
# 10     Bajaj       RED      5   5000      2          1.7

# %%
About_Bikes
# Out:
#         Make    Colour  GEARS  Price  Seats  Engine Size
# 0       jawa  MATBLACK      6   2300      2          2.9
# 1     bullet       Red      5   2000      2          3.5
# 2       jawa      Blue      6   2500      2          4.1
# 3        bmw     WHITE      6   4000      2          1.5
# 4   kawasaki     GREEN      6  20000      2          3.4
# 5        ktm    ORANGE      6   4000      2          1.6
# 6      honda      Blue      4   1000      2          4.4
# 7       hero      Blue      4   1200      2          2.9
# 8   kawasaki     White      6   1000      2          1.9
# 9        ktm     White      6   3000      2          1.5
# 10     Bajaj       RED      5   5000      2          1.7

# %% [markdown]
# ## Extensions
#
# Always remember, the best way to learn something new to is try it. Make mistakes. Ask questions, get things wrong, take note of the things you do most often. And don't worry if you keep making the same mistake, pandas has many ways to do the same thing and is a big library. So it'll likely take a while before you get the hang of it.
